# %%
import pandas as pd

# %%
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df_key=visa_df.keys()

col=[]
num=[]
for i in df_key:
    if visa_df[i].dtypes=='object':
        col.append(i)
    else:
        num.append(i)
col,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
colu=visa_df.columns
key=visa_df.keys()
col=[]
num=[]
for i , j in zip(key,colu):
    if j=='object':
        col.append(j)
    else:
        num.append(j)
col,num
# Out:
# ([],
#  ['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'no_of_employees',
#   'yr_of_estab',
#   'region_of_employment',
#   'prevailing_wage',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'])

# %% [markdown]
# **select dtypes**

# %%
cat=visa_df.select_dtypes(include='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **categorical column analysis**

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[1]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
type(visa_df['continent'])
# Out:
# pandas.core.series.Series

# %%
type(visa_df[['continent']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.loc[1:,'continent'])
# Out:
# pandas.core.series.Series

# %%
visa_df.iloc[:,[1]]

# %% [markdown]
# **raw data**

# %%
visa_df
visa_df['continent']  #only values
visa_df['continent'].values  #raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %% [markdown]
# **continent**

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# **Frequency table**

# %%
col=visa_df['continent']=='Asia'
col
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
col=visa_df['continent']=='Asia' # calculating only asia data and number of rows
visa_df[col]   #
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df[col])
# Out:
# 16861

# %%
import numpy as np

# %%
np.sum(col)
# Out:
# np.int64(16861)

# %%
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    if visa_df['continent']=='i':
        count.append(i)
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hh=visa_df['continent'].unique()
#       2 count=[]
#       3 for i in hh:
#
# NameError: name 'visa_df' is not defined

# %%
hh=visa_df['continent'].unique()
hh
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(np.sum(con))
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
c=visa_df['continent'].unique()
v=[168
h=pd.DataFrame(c,v,columns=['con','gh'])
h
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 c=visa_df['continent'].unique()
#       2 v=count
# ----> 3 h=pd.DataFrame(c,v,columns=['con','gh'])
#       4 h
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)    828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
#     838         )
# ...

# %%
list1=con
list2=count
k=pd.DataFrame(list1,list2)
k
# Out:
#        continent
# 16861      False
# 551        False
# 3292       False
# 3732       False
# 852        False
# 192        False

# %%
df1=pd.DataFrame(zip(con,count),
                 columns=['continent','number of frequency'])
df1
# Out:
#    continent  number of frequency
# 0      False                16861
# 1      False                  551
# 2      False                 3292
# 3      False                 3732
# 4      False                  852
# 5      False                  192

# %% [markdown]
# **value count**

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# **Bar chart**

# %%
visa_df['continent'].value_counts.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 visa_df['continent'].value_counts.keys()
#
# AttributeError: 'function' object has no attribute 'keys'

# %%
key=visa_df['continent'].keys()
key
# Out:
# RangeIndex(start=0, stop=25480, step=1)

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
plt.bar()


barchart 
pichart

# %%
visa_df.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 visa_df.keys()
#
# NameError: name 'visa_df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %%
visa_df.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_id'].value_counts()
# Out:
# case_id
# EZYV01       1
# EZYV02       1
# EZYV03       1
# EZYV04       1
# EZYV05       1
#             ..
# EZYV25476    1
# EZYV25477    1
# EZYV25478    1
# EZYV25479    1
# EZYV25480    1
# Name: count, Length: 25480, dtype: int64

# %%
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    if visa_df['continent']=='i':
        count.append(i)
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hh=visa_df['continent'].unique()
#       2 count=[]
#       3 for i in hh:
#
# NameError: name 'visa_df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %%
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    c = (visa_df['continent'] == i).sum()
    count.append(c)
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
c=visa_df['continent'].unique()

# %%
c
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
k=zip(c,count)
frequenct_table=pd.DataFrame(k,columns=['continents','hh'])

# %%
frequenct_table
# Out:
#       continents     hh
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    c=visa_df['continent']==i
    count.append(np.sum(c))
plt.bar(hh,count)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    c=visa_df['continent']==i
    count.append(np.sum(c))
plt.pie(count,labels=hh)
plt.show()

# %%
21 april

# %% [markdown]
# - frequency table we did from scrach also with method
# - **value count**
# - we selected a categorical and numerica; data types
# - **select types**
# - we can select a single column or multiple columns
# - **series or Dataframe
# - if any one give two list to you you can create a dataframe
# - clear difference between
# - series
# - data frame
# - values  **numpy format**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
plt.figure(figsize=(10,4))
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('continents')
plt.ylabel('No of applicant')
plt.title('Continent_bar_chart')
plt.savefig('continent.jpg')

# %%
plt.figure(figsize=(10,4))
cols=['Red','Green','Blue','Orange','Brown','Black']

plt.bar(keys,values,color=cols)
plt.xlabel('continents')

plt.ylabel('No of applicant')
plt.title('Continent_bar_chart')
plt.savefig('continent.jpg')

# %%
import matplotlib
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__all__',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_afm',
#  '_api',
#  '_blocking_input',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_bivar',
#  '_cm_listed',
#  '_cm_multivar',
#  '_color_data',
#  '_constrained_layout',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_image',
#  '_init_tests',
#  '_label_from_arg',
#  '_layoutgrid',
#  '_log',
#  '_logged_cached',
# ...

# %%
from matplotlib import

# %%
keys=visa_df.keys()

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
cat = []
num = []

for col in visa_df.columns:
    if visa_df[col].dtype == 'object':
        cat.append(col)
    else:
        num.append(col)
for i in cat[1:]:
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
cat = []
num = []

for col in visa_df.columns:
    if visa_df[col].dtype == 'object':
        cat.append(col)
    else:
        num.append(col)
cat

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('labels')
plt.ylabel('count')
plt.title(f'{i}_bar_chart')
plt.savefig(f'{i}.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %%
cat = []
num = []

for col in visa_df.columns:
    if visa_df[col].dtype == 'object':
        cat.append(col)
    else:
        num.append(col)
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.title(f'{i}_barchart')
    plt.savefig(f'{i}_bar.jpg')
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
hh=visa_df['continent'].unique()
count=[]
for i in hh:
    c=visa_df['continent']==i
    count.append(np.sum(c))
plt.pie(count,labels=hh)
plt.show()
