# %% [markdown]
# **Step 1 : Import packages**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step 2 : Create a Dataframe using list**

# %%
Names=['Ramesh','Suresh','Satish']
#pd.Dataframe (data ,index,columns)
pd.DataFrame(Names)
# Out:
#         0
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %%
pd.DataFrame(Names,'Names') Wrong
pd.DataFrame(Names,columns='Names']) Wrons bcoz accepted type is aray
multiple list
pd.DataFrame(Names,['Names'])   wrong
pd.DataFrame(Names,columns=['Names'])  Correct

# %%
Names=['Ramesh','Suresh','Satish']
#pd.Dataframe (data ,index,columns)
pd.DataFrame(Names,columns=['Names'])
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %% [markdown]
# **Step 3: Name the column**

# %%
Names=['Ramesh','Suresh','Satish']
#pd.Dataframe (data ,index,columns)
pd.DataFrame(Names,'Names') #wrong 
pd.DataFrame(Names,columns='Names')  #w
pd.DataFrame(Names,['Names']) #w
pd.DataFrame(Names,columns=['Names']) #right

# %%
Names=['Ramesh','Suresh','Satish']
pd.DataFrame(Names,columns=['Names']) #right
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %%
Names=['Ramesh','Suresh','Satish']
pd.DataFrame(Names,columns=['Naam']) #right
# Out:
#      Naam
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %% [markdown]
# **Step 4 : Change the index**

# %%
Names=['Ramesh','Suresh','Satish']
pd.DataFrame(Names,index=["a","b","c"],columns=['namw'])
# Out:
#      namw
# a  Ramesh
# b  Suresh
# c  Satish

# %% [markdown]
# **Step : 5 two columns**

# %%
Names=['Ramesh','Suresh','Satish']
Age=[20,22,35]
pd.DataFrame(columns=['name','age'])
# Out:
# Empty DataFrame
# Columns: [name, age]
# Index: []

# %%
Names=['Ramesh','Suresh','Satish']
Age=[20,22,35]
pd.DataFrame(columns=['name','age'])

# %%
Names=['Ramesh','Suresh','Satish']
age=[10,25,78]
pd.DataFrame(Names,index=["a","b","c"],columns=['namw'])

# %%
Names=['Ramesh','Suresh','Satish']
age=[10,25,78]
data=zip(Names,age)
cols=['Names','Age']
pd.DataFrame(data,columns=cols)
# Out:
#     Names  Age
# 0  Ramesh   10
# 1  Suresh   25
# 2  Satish   78

# %% [markdown]
# **Step 6: Add the data to empty data frame**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# selection or updatte we use square bracket[]
#function==()

# %%
Names=['Ramesh','Suresh','Satish']
age=[10,25,78]
data=zip(Names,age)
cols=['Names','Age']
employee=pd.DataFrame(data,columns=cols)
employee
# Out:
#     Names  Age
# 0  Ramesh   10
# 1  Suresh   25
# 2  Satish   78

# %%
employee['Names']
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# Name: Names, dtype: object

# %%
df=pd.DataFrame()
df['Names']    # it is do two operations selction or update

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Satish']
df
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Satish']
df['Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 df=pd.DataFrame()
# ...

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Satish']
df['Age']=[20,22]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 df=pd.DataFrame()
#       2 df['Names']=['Ramesh','Suresh','Satish']
# ----> 3 df['Age']=[20,22]
#       4 df
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
# ...

# %%
Errors 
1 key error=no colummn available
2 Value error=column length is mismatched

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Satish']
df['Age']=[20,22,24]
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Satish']
df['Age']=[20,22,24]
df

# %% [markdown]
# **Step 7 : already dataframe is available add the column to existing data frame**

# %%
df
# Out:
#     Names  Age     City
# 0  Ramesh   20      hyd
# 1  Suresh   22   mumbai
# 2  Satish   24  chennai

# %%
df['City']=['Pune','Mumbai','Delhi']
df
# Out:
#     Names  Age    City
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %% [markdown]
# **step 8: Rename the column**

# %% [markdown]
# - df.rename(mapper,index,columns,axis,inplace)
# - A mapper is simply a conversion table / translation rule.
# - “if you see this value, change it to that value”

# %%
#i want to change "City" to "city"
# do mapping for this for mapping we use dictionary {key value pair}
# create a dictionary
#d={'City':'city'}
# for this we need to change column
#where are you saying this to opython
#d={'City':'city'}
#df.rename(columns=d)
#df.rename(mapper,index,columns,axis,inplace)
d={'City':'city'}
df.rename(columns=d)
# Out:
#     Names  Age    city
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
d={'City':'city'} #columns
df.rename(d)   # index
df.rename(d,axis=0)  # index
df.rename(d,axis=1)  #column  work   row wise operation in column
df.rename(index=d)  # index
df.rename(columns=d)  # column  work
# Out:
#     Names  Age    city
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
df.rename(d,axis=1) 
df
# Out:
#     Names  Age    City
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
df.rename(d,axis=1)
# Out:
#     Names  Age    city
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
df.rename(d,axis=1) 
we need to overright for new answer than previous will not
    show when we run the code doublw
Overwrite means replacing old data with new data.

inplace means:

make changes directly in the original DataFrame

inplace=True → original data changes permanently
inplace=False → original data stays same, new result is returned

# %%
d={'City':'city'}
df.rename(columns=d)   # assume as axis =0 i need to change index  
# no chnage no error

# %%
df.rename(d)
# Out:
#     Names  Age    City
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
df.rename(d,axis=1)
# Out:
#     Names  Age    city
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %% [markdown]
# - use inplace for permanent changes

# %%
df.rename(d,axis=1,inplace=True)
df
# Out:
#     Names  Age    city
# 0  Ramesh   20    Pune
# 1  Suresh   22  Mumbai
# 2  Satish   24   Delhi

# %%
df.columns=['names','age','City']

# %%
df.index=['A','B','C']

# %%
df
# Out:
#     names  age    City
# A  Ramesh   20    Pune
# B  Suresh   22  Mumbai
# C  Satish   24   Delhi

# %%
axis=0 → work down the rows (column-wise)

This means the operation happens for each column.

axis=1 → work across columns (row-wise)

This means the operation happens for each row.

# %%
#i want to change "City" to "city"
#df.rename(mapper,index,columns,axis,inplace)
d={'City':'city'}
df.rename(columns=d)
# Out:
#      Names  Age     city     city
# 0   suhanu   20      hyd      hyd
# 1   ramesh   23   mumbai   mumbai
# 2  hjhfuhj   12  chennai  chennai

# %%
df=pd.DataFrame()
df['Names']=['suhanu','ramesh','hjhfuhj']
df['Age']=[20,23,12]
df['City']=['hyd','mumbai','chennai']
df
# Out:
#      Names  Age     City
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
#df.rename(mapper,index,columns,axis,inplace)
d={'City':'city'}
df.rename(columns=d)
# Out:
#      Names  Age     city
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
d={'City':'city'}
df.rename(d)
df.rename(d,axis=0)  # index
df.rename(d,axis=1)   #col==work
df.rename(d,axis=0)     # index
df.rename(index=d)
df.rename(columns=d)   #column work

# %%
d={'City':'city'}
df.rename(d,axis=0)
df
# Out:
#      Names  Age     City
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
d={'City':'city'}
df.rename(d,axis=0)
# Out:
#      Names  Age     City
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
df.rename(d,axis=1)
# Out:
#      Names  Age     city
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
df.rename(columns=d)
# Out:
#      Names  Age     city
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
df.columns=['name','age','citty']

# %%
df
# Out:
#       name  age    citty
# 0   suhanu   20      hyd
# 1   ramesh   23   mumbai
# 2  hjhfuhj   12  chennai

# %%
df.index=['A','B','C']

# %%
df
# Out:
#       name  age    citty
# A   suhanu   20      hyd
# B   ramesh   23   mumbai
# C  hjhfuhj   12  chennai

# %% [markdown]
# **Step 9 Drop the column**

# %%
i want to drop city column

# %%
df
# Out:
#     names  age    City
# A  Ramesh   20    Pune
# B  Suresh   22  Mumbai
# C  Satish   24   Delhi

# %%
df.drop('City',axis=1)   # here changes wont be permanent 
# when we write df old values will com 
# not writing df old new values will come
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22
# C  Satish   24

# %%
df.drop(columns=['City'])
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22
# C  Satish   24

# %%
df.drop('City',axis=1,inplace=True)
df   # writhing df old values will come 


### we want to use inplace for permanent changes
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22
# C  Satish   24

# %%
df.drop('City')   error
df.drop('City',axis=0)  error
df.drop(index=['City'])  error
df.drop('City',axis=1)  work
df.drop(columns=['City']) work

# %%
i want to drop satish

# %%
df.drop('C')
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22

# %%
df   #we need to provide inplace for permanent changes
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22
# C  Satish   24

# %%
df.drop('C',inplace=True)

# %%
df
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22

# %%
df.drop()

# %% [markdown]
# - change the index
# -  add the columns
# -  add the data to empty dataframe
# -  rename the column
# -   rename all the column a

# %%
import pandas as pd

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.df['Name']=['suresh','ramesh','satish']
pd.df['age']=[20,22,35]
pd.df['City']=['hyd','banglore','pune']
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pd.df['Name']=['suresh','ramesh','satish']
#       2 pd.df['age']=[20,22,35]
#       3 pd.df['City']=['hyd','banglore','pune']
#
# AttributeError: module 'pandas' has no attribute 'df'

# %%
import pandas as pd
df=pd.DataFrame()
pd.df['Name']=['suresh','ramesh','satish']
pd.df['age']=[20,22,35]
pd.df['City']=['hyd','banglore','pune']
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 df=pd.DataFrame()
# ----> 3 pd.df['Name']=['suresh','ramesh','satish']
#       4 pd.df['age']=[20,22,35]
#       5 pd.df['City']=['hyd','banglore','pune']
#
# AttributeError: module 'pandas' has no attribute 'df'

# %%
import pandas as pd

df = pd.DataFrame()

df['Name'] = ['suresh', 'ramesh', 'satish']
df['age'] = [20, 22, 35]
df['City'] = ['hyd', 'bangalore', 'pune']

print(df)
# Out:
#      Name  age       City
# 0  suresh   20        hyd
# 1  ramesh   22  bangalore
# 2  satish   35       pune

# %% [markdown]
# **replace**

# %%
df.replace(1,2)
df
# Out:
#      Name  age       City
# 0  suresh   20        hyd
# 1  ramesh   22  bangalore
# 2  satish   35       pune

# %%
df.replace(to_replace,value)

# %%
df.replace('hyd','chennaai')
# Out:
#      Name  age       City
# 0  suresh   20   chennaai
# 1  ramesh   22  bangalore
# 2  satish   35       pune

# %%
Names=['Ramesh','Suresh','Satish']
City=['Hyd','Blr','Pune']
Age=[20,22,24]
data=zip(Names,City,Age)
df=pd.DataFrame(data,index=['A','B','C'],
                columns=['Names','City','Age'])
####################################
df.drop('City',axis=1,inplace=True)
df.drop('C',inplace=True)

# %%
df
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   22

# %% [markdown]
# **Session 67**

# %% [markdown]
# - create a dataframe
# - name the column
# - change the index
# - add the data to empty dataframe
# - add the column to existing dataframe
# - rename the column
# - rename all the column and all the index at a time
# - drop the column
# - drop the index

# %% [markdown]
# **step 10  replace**

# %%
import pandas as pd

df = pd.DataFrame()

df['Name'] = ['suresh', 'ramesh', 'satish',]
df['age'] = [20, 22, 24]
df['City'] = ['Hyd', 'Bangalore', 'Pune']

df
# Out:
#      Name  age       City
# 0  suresh   20        Hyd
# 1  ramesh   22  Bangalore
# 2  satish   24       Pune

# %%
df.replace('Hyd','Chennai')
# Out:
#      Name  age       City
# 0  suresh   20    Chennai
# 1  ramesh   24  Bangalore
# 2  satish   35       Pune

# %%
df = pd.DataFrame()

df['Name'] = ['suresh', 'ramesh', 'satish','Mahesh']
df['age'] = [20, 22, 24,24]
df['City'] = ['Hyd', 'Bangalore', 'Pune','Hyd']
df
# Out:
#      Name  age       City
# 0  suresh   20        Hyd
# 1  ramesh   22  Bangalore
# 2  satish   24       Pune
# 3  Mahesh   24        Hyd

# %%
df.replace('Hyd','Chennai')
# Out:
#      Name  age       City
# 0  suresh   20    Chennai
# 1  ramesh   22  Bangalore
# 2  satish   24       Pune
# 3  Mahesh   24    Chennai

# %%
df['Marks']=[25,24,23,22]

# %%
df
# Out:
#      Name  age       City  Marks
# 0  suresh   20        Hyd     25
# 1  ramesh   22  Bangalore     24
# 2  satish   24       Pune     23
# 3  Mahesh   24        Hyd     22

# %%
df.replace(24,20) #when we chnage marks 24 than age also will change
# Out:
#      Name  age       City  Marks
# 0  suresh   20        Hyd     25
# 1  ramesh   22  Bangalore     20
# 2  satish   20       Pune     23
# 3  Mahesh   20        Hyd     22

# %%
#all the data in same will change
#all the column data will change

# %%
df['Marks'].replace(24,20,inplace=True)
df
# Out:
# C:\Users\suhan\AppData\Local\Temp\ipykernel_26616\2409022249.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].replace(24,20,inplace=True)
#      Name  age       City  Marks
# 0  suresh   20        Hyd     25
# 1  ramesh   22  Bangalore     20
# 2  satish   24       Pune     23
# 3  Mahesh   24        Hyd     22

# %%
i want to change city name to chennai
for thr candidates who has age = 24

# %%
  here both side hyd chnage all chnage but i dont want change

# %%
df['Marks']=[45,23,89]
df
# Out:
#      Name  age       City  Marks
# 0  suresh   20        hyd     45
# 1  ramesh   24  bangalore     23
# 2  satish   35       pune     89
# 3  mahesh   34        hyd     45

# %%
df['Marks'].replace(23,77.inplace=True)
# Out:
# <>:1: SyntaxWarning: invalid decimal literal
# <>:1: SyntaxWarning: invalid decimal literal
# C:\Users\suhan\AppData\Local\Temp\ipykernel_10020\3050866215.py:1: SyntaxWarning: invalid decimal literal
#   df['Marks'].replace(23,77.inplace=True)
#   Cell In[15], line 1
#     df['Marks'].replace(23,77.inplace=True)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# **step 11 np.where**

# %%
import numpy as np

# %%
i want to change city name to chennai
for the candidates who has age =24

# %%
np.where(condition,True,False)
age==24
Chennai  if condition is true print chennai
Nochange   if cond is false no change

# %%
# i need to apply condition on age column
# we need to slect a column
df['age']
# Out:
# 0    20
# 1    22
# 2    24
# 3    24
# Name: age, dtype: int64

# %%
con=df['age']==24
true='Chennai'
false=df['City']

# %%
np.where(con,true,'aaa')
# Out:
# array(['aaa', 'aaa', 'Chennai', 'Chennai'], dtype='<U7')

# %%
np.where(con,true,false)
# Out:
# array(['Hyd', 'Bangalore', 'Chennai', 'Chennai'], dtype=object)

# %%
df['City']=np.where(con,true,false)

# %%
df
# Out:
#      Name  age       City  Marks
# 0  suresh   20        Hyd     25
# 1  ramesh   22  Bangalore     20
# 2  satish   24    Chennai     23
# 3  Mahesh   24    Chennai     22

# %% [markdown]
# **loc-iloc**

# %%
df.loc[rows,columns]
rows are index numbers similar to list slice
l[start:stop:step]
column are names any cloumn name we can provide
df.iloc[rows,columns]
rows and columns are index numbers similar to list slice
l[start:stop:step]

# %%
df.loc[[1,2,3]]
# Out:
#      Name  age       City  Marks
# 1  ramesh   22  Bangalore     20
# 2  satish   24    Chennai     23
# 3  Mahesh   24    Chennai     22

# %%
rows=[1,2,3]
cols=['age','City']
df.loc[rows,cols]
# Out:
#    age       City
# 1   22  Bangalore
# 2   24    Chennai
# 3   24    Chennai

# %%
rows=[1,2,3]
df.iloc[rows]
# Out:
#      Name  age       City  Marks
# 1  ramesh   22  Bangalore     20
# 2  satish   24    Chennai     23
# 3  Mahesh   24    Chennai     22

# %%
rows=[1,2,3]
cols=[1,2]
df.iloc[rows,cols]
# Out:
#    age       City
# 1   22  Bangalore
# 2   24    Chennai
# 3   24    Chennai

# %%
cols=[1,2]
df.iloc[1:3,cols]
# Out:
#    age       City
# 1   22  Bangalore
# 2   24    Chennai

# %%
cols=['age','City']
df.loc[1:3,cols]
# Out:
#    age       City
# 1   22  Bangalore
# 2   24    Chennai
# 3   24    Chennai

# %%
cols=[1,2]
df.iloc[1:3,cols]
# Out:
#    age       City
# 1   22  Bangalore
# 2   24    Chennai

# %%
df.loc[0]
# Out:
# Name     suresh
# age          20
# City        Hyd
# Marks        25
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Name        ramesh
# age             22
# City     Bangalore
# Marks           20
# Name: 1, dtype: object

# %%
df.loc[3]
# Out:
# Name      Mahesh
# age           24
# City     Chennai
# Marks         22
# Name: 3, dtype: object

# %%
4th row nahi hai toh add krna

# %% [markdown]
# **appending a data**

# %%
df.loc[4]=['Anish',26,'Mumbai',25]

# %%
df

#df.loc[len(df)]=['Anish',26,'Mumbai',25]   we can do like this also i do 
# this than two values will come
# Out:
#      Name  age       City  Marks
# 0  suresh   20        Hyd     25
# 1  ramesh   22  Bangalore     20
# 2  satish   24    Chennai     23
# 3  Mahesh   24    Chennai     22
# 4   Anish   26     Mumbai     25
# 5   Anish   26     Mumbai     25

# %% [markdown]
# **step 13 how t save the data frame**

# %%
# directory : where is the file available
# name =: what is the name of the file
# extension : what is the type of the file

#dataframe variable==df
#name  :  student
#exten  : .csv and .xlsx
df.to_csv('student.csv')

# %%
pd.read_csv('student.csv')
# Out:
#    Unnamed: 0    Name  age       City  Marks
# 0           0  suresh   20        Hyd     25
# 1           1  ramesh   22  Bangalore     20
# 2           2  satish   24    Chennai     23
# 3           3  Mahesh   24    Chennai     22
# 4           4   Anish   26     Mumbai     25
# 5           5   Anish   26     Mumbai     25

# %%
df.to_excel('student.xlsx')

# %%
df.to_csv('student.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\suhan\OneDrive\Documents\Naresh_IT\EDA

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Session_1_Basics.ipynb', 'student.csv', 'student.xlsx']

# %%
import os
os.startfile('student.xlsx')

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\bank.csv")
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\bank.csv",
            sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\Visadataset.csv")

# %% [markdown]
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes
# - isnull
# - info

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.isnull
# Out:
# <bound method DataFrame.isnull of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=visa_df.columns
cols.tolist()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols=visa_df.columns
cols.tolist().index('continent')
# Out:
# 1

# %% [markdown]
# **data types**

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
   # ()  is needed and you not provided than bound methos will come
   # () is not needed than not callable come

# %%
data_types=visa_df.dtypes

# %% [markdown]
# - series does not have any column name
# - data frame have column name
# - series is a kry value pair

# %%
data_types=visa_df.dtypes

# %%
type(data_types)
# Out:
# pandas.core.series.Series

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - series is a key value pair
# - series kind of a dictionary

# %%
data_types.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data_types.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
data_types.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data_types.keys()
data_types.values
##################
data_types.index
data_types.values

# %% [markdown]
# - When we have a series
# - we need to make to separate lists
# - so that we can able to create a dataframe

# %%
visa_df.dtypes # data frame (we starts from here)
keys=visa_df.dtypes.keys() # types series
values=visa_df.dtypes.values #keys
df1=pd.DataFrame(zip(keys,values),  #values
             columns=['Continent','Datatype'])
df1
# Out:
#                 Continent Datatype
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %% [markdown]
# - separate categorical and numerical column in different list

# %%
keys=visa_df.dtypes.keys()
values=visa_df.dtypes.values
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(i)
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
cat = []
num = []

for col in visa_df.columns:
    if visa_df[col].dtype == 'object':
        cat.append(col)
    else:
        num.append(col)

cat, num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
keys=visa_df.keys()
keys
cat=[]
num=[]
for i in keys:
    if visa_df[i].dtypes=='object':
        cat.append(i)
    else:
        num.append(i)

cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
visa_df.iloc[100:105,3:7]   #dataframe
# Out:
#     has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 100                  Y                     N             2227         2007
# 101                  Y                     N              334         2007
# 102                  Y                     N              224         2008
# 103                  Y                     N              367         1982
# 104                  Y                     N              306         2003

# %%
visa_df.loc[100:105]  #s
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 100  EZYV101           Asia              Master's                  Y
# 101  EZYV102           Asia              Master's                  Y
# 102  EZYV103           Asia            Bachelor's                  Y
# 103  EZYV104           Asia             Doctorate                  Y
# 104  EZYV105           Asia              Master's                  Y
# 105  EZYV106  North America             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 101                     N              334         2007              Midwest
# 102                     N              224         2008              Midwest
# 103                     N              367         1982                 West
# 104                     N              306         2003            Northeast
# ...

# %%
visa_df.iloc[100] #series
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.loc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[[100]]       #dataframe
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.loc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.loc[[100,200,300],]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:,[3,6,9]]
# Out:
#       has_job_experience  yr_of_estab unit_of_wage
# 0                      N         2007         Hour
# 1                      Y         2002         Year
# 2                      N         2008         Year
# 3                      N         1897         Year
# 4                      Y         2005         Year
# ...                  ...          ...          ...
# 25475                  Y         2008         Year
# 25476                  Y         2006         Year
# 25477                  Y         1910         Year
# 25478                  Y         1887         Year
# 25479                  Y         1960         Year
#
# [25480 rows x 3 columns]

# %%
visa_df.iloc[:,3]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[3]]
# Out:
#       has_job_experience
# 0                      N
# 1                      Y
# 2                      N
# 3                      N
# 4                      Y
# ...                  ...
# 25475                  Y
# 25476                  Y
# 25477                  Y
# 25478                  Y
# 25479                  Y
#
# [25480 rows x 1 columns]

# %%
visa_df.iloc[:,:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = []
num = []

for col, dtype in zip(visa_df.columns, visa_df.dtypes):
    if dtype == 'object':
        cat.append(col)
    else:
        num.append(col)

cat, num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
bank_df=pd.read_csv(r"C:\Users\suhan\OneDrive\Documents\Naresh_IT\Data Files\bank.csv",
            sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
head
tail
shape
size
columns
dtypes
isnull
info

# %%
bank_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_df.shape
# Out:
# (4521, 17)

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.size
# Out:
# 76857

# %%
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bank_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
keys=bank_df.keys()
keys
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
keys=bank_df.keys()
cat=[]
num=[]
for i in keys:
    if bank_df[i].dtypes=='object':
        cat.append(i)
    else:
        num.append(i)
cat,num
# Out:
# (['job',
#   'marital',
#   'education',
#   'default',
#   'housing',
#   'loan',
#   'contact',
#   'month',
#   'poutcome',
#   'y'],
#  ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'])
